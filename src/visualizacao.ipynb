# %%
import pandas as pandas

# %%
metricasFile = pandas.read_csv('metricasGerais.csv')

from IPython.display import display

display(metricasFile)
# Out:
#               NOME  QTD_VERTICES  QTD_ARESTAS  QTD_ARCOS  \
# 0             BHW1          12.0         11.0       22.0
# 1            BHW10          78.0          0.0      197.0
# 2            BHW11          78.0          0.0      197.0
# 3            BHW12         141.0          0.0      381.0
# 4            BHW13         141.0          0.0      381.0
# ..             ...           ...          ...        ...
# 405  mgval_0.50_8C          30.0         28.0       55.0
# 406  mgval_0.50_9A          50.0         32.0      100.0
# 407  mgval_0.50_9B          50.0         44.0       76.0
# 408  mgval_0.50_9C          50.0         42.0       83.0
# 409  mgval_0.50_9D          50.0         38.0       93.0
#
#      QTD_VERTICES_REQUERIDOS  QTD_ARESTAS_REQUERIDAS  QTD_ARCOS_REQUERIDOS  \
# 0                        7.0                    11.0                  11.0
# 1                       40.0                     0.0                 102.0
# ...

# %%
intermediacaoFile = pandas.read_csv('intermediacoes.csv')

nomes_grafos = intermediacaoFile['NOME'].unique()

for grafo in nomes_grafos:
    print(f"📁 Grafo: {grafo}")
    df_grafo = intermediacaoFile[intermediacaoFile['NOME'] == grafo]
    display(df_grafo.reset_index(drop=True))
# Out:
# 📁 Grafo: BHW1
#     NOME   VERTICE   INTERMEDIACAO
# 0   BHW1       1.0        0.136364
# 1   BHW1       2.0        0.166667
# 2   BHW1       3.0        0.045455
# 3   BHW1       4.0        0.000000
# 4   BHW1       5.0        0.106061
# 5   BHW1       6.0        0.287879
# 6   BHW1       7.0        0.166667
# 7   BHW1       8.0        0.121212
# 8   BHW1       9.0        0.106061
# 9   BHW1      10.0        0.045455
# 10  BHW1      11.0        0.000000
# 11  BHW1      12.0        0.166667
# 📁 Grafo: BHW10
#      NOME   VERTICE   INTERMEDIACAO
# 0   BHW10       1.0        0.000000
# 1   BHW10       2.0        0.049617
# 2   BHW10       3.0        0.000000
# 3   BHW10       4.0        0.098901
# 4   BHW10       5.0        0.060273
# ..    ...       ...             ...
# 73  BHW10      74.0        0.000000
# 74  BHW10      75.0        0.095904
# 75  BHW10      76.0        0.124875
# 76  BHW10      77.0        0.028305
# 77  BHW10      78.0        0.000000
#
# [78 rows x 3 columns]
# ...
